# %%
#W2A1
print("Hello World!")
# Out:
# Hello World!

# %%
#W2A2
a=input()
print("Hello",a)
# Out:
# Hello 1

# %%
#W2A3
a,b=map(int,input().split())
print(a+b,a-b,a*b,a//b,a%b,sep="\n")
print(round(a/b,2))
# Out:
# 3
# -1
# 2
# 0
# 1
# 0.5

# %%
#W2A4
a=list(map(float,input().split())) 
print(round((a[0]+a[1]+a[2]+(a[3]+a[4])*2+a[5]*3)/10,2))
# Out:
# 4.2

# %%
#W2A5
a,b=map(int,input().split())
print(a**b)
# Out:
# 8

# %%
#W2A6
a=input()
b=ord(a)
while b<97 or b>122:
    a=input("Nhap lai: ")
    b=ord(a)
print(ord(a))
a=a.upper()
print(a)
# Out:
# 97
# A

# %%
#W2A7
A= ((13 ** 2) * 3) + 5 
B = 13 ** 2*3 + 5
print(A)
print(B)
# Out:
# 512
# 512

# %%
#W2A8
C=float(input())
print(round(9/5*C+32,2))
# Out:
# 42.08

# %%
#W2A9   
x=float(input())
x+=x*0.1+x*0.3+10
print(round(x,2))
# Out:
# 11.4

# %%
#W2A10
a=input().split()
a.reverse() 
print("Hi",a[0]+",", a[1],"and", a[2])
# Out:
# Hi nhe, chao and xin

# %%
#W2A11
a=int(input())
b=int(input())
print(a*3600+b*60)
# Out:
# 3720

# %%
#W2A12
n=int(input())
print(6*n**2)
# Out:
# 150

# %%
#W2A13
a,b=map(int,input().split())
print((a*b)%10)
# Out:
# 2

# %%
#W2A14
a,b=map(int,input().split())
a,b=b,a 
print(a,b)
# Out:
# 2 1

# %%
#W2A15
n=int(input())
print(n*'*')
# Out:
# *****

# %%
#W2A16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print("   * ")
print("  *** ")
print(" ***** ")
# Out:
#    *
#   ***
#  *****

# %%
#w2A18
print("### ##   ### ###\n #  #  #  #  #\n #  #   # #  #\n #  #  #  #  #\n #  ##    #  #")
# Out:
# ### ##   ### ###
#  #  #  #  #  #
#  #  #   # #  #
#  #  #  #  #  #
#  #  ##    #  #

# %%
#W219
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W220
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W221
for i in range(10):
    print("Hello world")
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
